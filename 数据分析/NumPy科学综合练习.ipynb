# %%
'''
题目一  温度数据分析
城市一周最高温度 [28,30,35,36,29,32,34]
计算平均气温 ,最高气温，最低气温
找出超过30度的天气
'''
import numpy as np
temps = np.array([28,30,35,36,29,32,34])
print("平均气温：",'%.2f'%np.mean(temps))
print("最高气温：",np.max(temps))
print("最低气温：",np.min(temps))
print("超出30度的天数：",np.sum(temps>30))
# Out:
# 平均气温： 32.00
# 最高气温： 36
# 最低气温： 28
# 超出30度的天数： 4
